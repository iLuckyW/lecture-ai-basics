# %% [markdown]
# Lecture: AI I - Basics
#
# Previous:
# [**Chapter 3.3: Visualisation with Matplotlib**](../03_data/03_matplotlib.ipynb)
#
# ---

# %% [markdown]
# # Chapter 3.4: Visualisation with Seaborn
#
# - [Seaborn](#seaborn)
# - [Gallery](#gallery)
# - [Themes](#themes)
# - [Relplot](#relplot)
# - [Displot](#displot)
# - [Pairplot](#pairplot)
# - [Catplot](#catplot)]
#
# ## Seaborn
#
# [Seaborn](https://seaborn.pydata.org/tutorial.html) is a high-level data visualization library built on top of Matplotlib. While Matplotlib provides the essential plotting framework, Seaborn extends it with a focus on statistical graphics, aesthetics, and simplicity. This makes it especially valuable for data analysis and teaching, where quick and meaningful visualizations are essential.
#
# One of Seaborn’s strengths is its ability to create visually appealing plots with minimal code. Default themes and color palettes are designed to make figures more readable and presentation-ready out of the box, without requiring extensive manual styling. Seaborn also integrates tightly with pandas DataFrames, allowing you to directly pass columns as arguments without reshaping data.
#
# ## Gallery
#
# following the link below to explore a wide range of examples showcasing the capabilities of Seaborn:

# %%
from IPython.display import IFrame

IFrame(
    "https://seaborn.pydata.org/examples/index.html",
    width="100%",
    height=750,
)
# Out:
#         <iframe
#             width="100%"
#             height="750"
#             src="https://seaborn.pydata.org/examples/index.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Import Convention
#
# Seaborn is conventionally imported with the following import:

# %%
import seaborn as sns

# %% [markdown]
# ## Themes
#
# One of the strengths of Seaborn is its ability to apply [themes](https://seaborn.pydata.org/generated/seaborn.set_theme.html) that instantly improve the appearance of plots. These themes adjust elements like background color, gridlines, ticks, and overall style, so your plots look cleaner and more consistent without extra manual formatting.
#
# Seaborn provides five built-in themes that can be set with `sns.set_theme(style=...)`:
# - **darkgrid (default)**: a dark background grid, useful for most data analysis tasks.
# - **whitegrid**: a white background with gridlines, often used for categorical plots like boxplots.
# - **dark**: a dark background without gridlines, good for highlighting bold lines or scatterplots.
# - **white**: a minimal white background, often used in publications.
# - **ticks**: similar to white, but adds ticks for a more traditional plotting style.

# %%
sns.set_theme(style="darkgrid")

# %% [markdown]
# ## Relplot
#
# [Seaborn](https://seaborn.pydata.org/tutorial/relational.html), `relplot` is a figure-level function for creating relational plots such as scatterplots and lineplots. It’s not “replot,” but rather short for relational plot. Unlike axis-level functions like sns.`scatterplot` or `sns.lineplot`, `relplot` adds an extra layer of flexibility by combining these into a unified interface and supporting faceting (subplots based on categorical variables).

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(
    data=tips, x="total_bill", y="tip", hue="size"
)

# %%
tips = sns.load_dataset("tips")
sns.relplot(
    data=tips, x="total_bill", y="tip", hue="size", kind="line"
)

# %% [markdown]
# ## Displot
#
# In [Seaborn](https://seaborn.pydata.org/tutorial/distributions.html), displot is a figure-level function designed for visualizing the distribution of a dataset. It serves as a powerful extension of simple histograms, offering multiple ways to explore how values are spread across a variable.
#
# **Multiple kinds of plots**:
# - `kind="hist"`: histogram (default).
# - `kind="kde"`: kernel density estimate.
# - `kind="ecdf"`: empirical cumulative distribution function.
#
# **Faceting**: Like other figure-level functions, displot supports col and row to split data into multiple subplots.

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", element="step")

# %% [markdown]
# ## Pairplot
#
# The `pairplot` function in Seaborn is a figure-level tool designed to visualize pairwise relationships in a dataset. It automatically creates a grid of plots where each variable is compared against every other variable, making it a powerful tool for exploratory data analysis.

# %%
sns.pairplot(penguins)

# %% [markdown]
# ## Catplot
#
# The catplot function in Seaborn is a figure-level function designed for visualizing categorical data. It provides a unified interface to multiple categorical plot types (like barplots, boxplots, and violinplots), making it easier to compare distributions or summaries across categories.
#
# **Kinds of plots**: controlled with `kind=...`
# - `"strip":` individual observations as points.
# - `"swarm":` non-overlapping points to better show distributions.
# - `"box":` box-and-whisker plots showing spread and quantiles.
# - `"violin":` combines boxplot with a KDE distribution.
# - `"bar":` shows estimates (by default the mean) with confidence intervals.
# - `"count":` counts of observations in each category.
# - `"point":` mean + confidence interval, plotted as points with lines.
#
# **Faceting**: Like relplot and displot, catplot supports row and col arguments to generate grids of plots based on categorical variables.

# %%
sns.catplot(
    data=tips, x="time", y="total_bill", hue="sex",
    kind="violin", inner="stick", split=True, palette="pastel",
)

# %% [markdown]
# ---
#
# Lecture: AI I - Basics
#
# Exercise: [**Exercise 3.4: Visualisation with Seaborn**](../03_data/exercises/04_seaborn.ipynb)
#
# Next: [**Chapter 3.5: Preprocessing with Pandas**](../03_data/05_preprocessing.ipynb)
